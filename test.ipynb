# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ZIPファイル内のファイルの数を確認する

# %%
import zipfile

# ZIPファイルのパス
zip_path = '/content/drive/My Drive/signate/test.zip'

# ZIPファイル内のファイル一覧を取得
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    file_list = zip_ref.namelist()  # ZIP内のファイル名一覧を取得

# ファイル一覧を表示
print("Files in ZIP:")
for file in file_list:
    print(file)

# ZIP内のファイル数を表示
print(f"\nNumber of files in ZIP: {len(file_list)}")
# Out:
# Files in ZIP:
# train.csv
#
# Number of files in ZIP: 1

# %% [markdown]
# ZIPファイルを解凍する

# %%
import zipfile
import os


# train_ZIPファイルのパス
zip_path = '/content/drive/My Drive/signate/test.zip'
extract_path = '/content/drive/My Drive/signate/extracted_test'

# 解凍
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# 解凍されたファイルを確認
print("Extracted files:", os.listdir(extract_path))
# Out:
# Extracted files: ['train.csv']

# %%
# BigQueryライブラリのインストール
# !pip install google-cloud-bigquery

# 認証
from google.colab import auth
auth.authenticate_user()

# %%
from google.cloud import bigquery

# クライアントの初期化
client = bigquery.Client()

# %% [markdown]
# testデータセットを分割する

# %%
import pandas as pd

# 入力ファイルパス
input_file = '/content/drive/My Drive/signate/extracted_test/test.csv'

# 保存先のGoogle Driveパス
output_folder = '/content/drive/My Drive/signate/test_chunked_files/'

# チャンクサイズ（行数）
chunk_size = 90000  # 必要に応じて調整

# ファイルをチャンクごとに保存
for i, chunk in enumerate(pd.read_csv(input_file, chunksize=chunk_size)):
    output_file = f'{output_folder}chunk_{i}.csv'
    chunk.to_csv(output_file, index=False)
    print(f'Chunk {i} saved to {output_file}')
# Out:
# <ipython-input-17-1a0eb259285f>:13: DtypeWarning: Columns (39,40,42,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(pd.read_csv(input_file, chunksize=chunk_size)):
# Chunk 0 saved to /content/drive/My Drive/signate/train_chunked_files/chunk_0.csv
# <ipython-input-17-1a0eb259285f>:13: DtypeWarning: Columns (39,40,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(pd.read_csv(input_file, chunksize=chunk_size)):
# Chunk 1 saved to /content/drive/My Drive/signate/train_chunked_files/chunk_1.csv
# <ipython-input-17-1a0eb259285f>:13: DtypeWarning: Columns (39,40,42,55,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(pd.read_csv(input_file, chunksize=chunk_size)):
# Chunk 2 saved to /content/drive/My Drive/signate/train_chunked_files/chunk_2.csv
# ...

# %% [markdown]
# # データの形状、列名、headを確認する

# %%
import pandas as pd
import unicodedata
import re


test_path = '/content/drive/My Drive/signate/extracted_test/test.csv'
# CSVデータをDaskで読み込む
test_data = pd.read_csv(test_path, low_memory=False)


# データの形状（行数と列数）
print(f"Rows: {test_data.shape[0]}, Columns: {test_data.shape[1]}")

# 列名とデータ型
print(test_data.info())

# データの一部を表示
print(test_data.head())
# Out:
# Rows: 384540, Columns: 152
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384540 entries, 0 to 384539
# Columns: 152 entries, index to free_rent_gen_timing
# dtypes: float64(89), int64(16), object(47)
# memory usage: 445.9+ MB
# None
#    index  target_ym building_id  building_status building_create_date  \
# 0      0     202207     a372446                1  2014-06-27 20:30:14
# 1      1     202301     a276097                1  2014-06-28 02:47:45
# 2      2     202307     a290359                1  2014-06-27 21:18:44
# 3      3     202207     a200797                1  2014-06-27 20:22:54
# 4      4     202201     a333901                1  2014-06-27 23:48:22
#
#   building_modify_date  building_type    building_name  building_name_ruby  \
# 0  2024-02-09 00:10:05              3       シャーメゾンエランA                 NaN
# 1  2024-08-15 02:24:34              1          マルコフォート                 NaN
# 2  2024-04-01 19:59:13              3      リバーサイドハウス松浪                 NaN
# ...

# %% [markdown]
# # 欠損値の数と%を確認する

# %%
import pandas as pd

# データのパスを指定
test_path = '/content/drive/My Drive/signate/extracted_test/test.csv'

# CSVデータをpandasで読み込む
test_data = pd.read_csv(test_path, low_memory=False)

# 重複を削除（すべての列で完全に一致する重複を削除）
test_data_cleaned = test_data.drop_duplicates()

# 欠損値の詳細を確認
missing = test_data_cleaned.isnull().sum().sort_values(ascending=False)
missing_percent = (missing / len(test_data_cleaned)) * 100

# 欠損値情報をデータフレームにまとめる
missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing Percent': missing_percent
}).sort_values(by='Missing Count', ascending=False)

# 欠損値がある列のみ表示
# missing_df = missing_df[missing_df['Missing Count'] > 0]

# 結果を表示
print("欠損値の詳細:")
print(missing_df)
# Out:
# 欠損値の詳細:
#                       Missing Count  Missing Percent
# name_ruby                    384540        100.00000
# land_shidou_a                384540        100.00000
# land_shidou_b                384540        100.00000
# building_name_ruby           384540        100.00000
# school_jun_code              384536         99.99896
# ...                             ...              ...
# statuses                          0          0.00000
# building_create_date              0          0.00000
# building_modify_date              0          0.00000
# building_type                     0          0.00000
# index                             0          0.00000
#
# [152 rows x 2 columns]

# %% [markdown]
# # 不要な列を削除する

# %%
import os


# 欠損値が20%以上の列を削除
threshold = 0.2
columns_to_drop_missing = missing_df[missing_df['Missing Percent'] > threshold * 100].index

# 指定された追加の列を削除
additional_columns_to_drop = [
    'building_id', 'building_create_date', 'building_modify_date', 'building_name', 'homes_building_name', 'unit_id',
    'building_tag_id', 'unit_id', 'unit_name', 'room_floor', 'unit_tag_id', 'bukken_id', 'snapshot_modify_date',
    'timelimit_date', 'flg_open', 'flg_own', 'bukken_type', 'empty_contents', 'nl', 'el', 'rosen_name1',
    'usable_status', 'statuses','floor_count', 'snapshot_create_date', 'room_count', 'floor_plan_code',
    'new_date','dwelling_unit_window_angle','building_status', 'building_type', 'unit_area', 'parking_kubun',  'room_kaisuu'
]

# 削除対象から除外する列をリスト化
exclude_columns = ['land_youto', 'land_toshi', 'land_youseki', 'land_kenpei', 'eki_name1']

# 削除対象列のリストを作成（除外する列を削除）
columns_to_drop = list(
    set(columns_to_drop_missing).union(set(additional_columns_to_drop)) - set(exclude_columns)
)

# データフレームから列を削除
df_cleaned = test_data.drop(columns=columns_to_drop, errors='ignore')

# 削除された列を表示
print(f"削除された列: {list(columns_to_drop)}")

# 残っている列を表示
print(f"残っている列: {list(df_cleaned.columns)}")

# 新しいデータフレームの形状を確認
print(f"新しいデータフレームの形状: {df_cleaned.shape}")

# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/test/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "test_selected.csv")

# データをCSVとして保存
df_cleaned.to_csv(output_file_path, index=False)

print(f"データが保存されました: {output_file_path}")
# Out:
# 削除された列: ['name_ruby', 'building_name', 'floor_plan_code', 'bukken_type', 'building_land_area', 'snapshot_land_shidou', 'flg_open', 'building_land_chimoku', 'school_ele_code', 'reform_interior_other', 'unit_count', 'usable_date', 'timelimit_date', 'parking_money_tax', 'reform_interior_date', 'land_chisei', 'homes_building_name', 'super_distance', 'parking_number', 'est_other_name', 'rosen_name2', 'building_modify_date', 'money_shuuzenkikin', 'land_setback_flg', 'total_floor_area', 'land_area_all', 'money_sonota3', 'bus_time1', 'land_area_kind', 'unit_name', 'snapshot_create_date', 'land_mochibun_b', 'usable_status', 'money_sonota_str1', 'snapshot_land_area', 'bus_stop2', 'free_rent_duration', 'reform_etc', 'traffic_other', 'school_jun_distance', 'money_sonota_str2', 'shopping_street_distance', 'money_rimawari_now', 'est_other_distance', 'building_create_date', 'empty_contents', 'reform_place_other', 'genkyo_code', 'bus_time2', 'management_association_flg', 'dwelling_unit_window_angle'
# ...

# %% [markdown]
# # ユニークな値を確認する

# %%
# データのパスを指定
test_path = '/content/drive/My Drive/signate/test/test_selected.csv'

# CSVデータをpandasで読み込む
test_data = pd.read_csv(test_path, low_memory=False)

# ユニークな値を取得
unique = test_data['full_address'].unique()

# ユニークな値を確認
print("ユニークな値:")
print(unique)

# ユニークな値の数を確認
num_unique = test_data['full_address'].nunique()
print(f"ユニークな値の数: {num_unique}")
# Out:
# ユニークな値:
# ['山口県山陽小野田市大字西高泊618-12' '東京都調布市菊野台3丁目3-3' '大阪府泉佐野市下瓦屋1丁目2-48' ...
#  '新潟県見附市上新田町2-11' '東京都国立市中3丁目10' '東京都墨田区向島3丁目39-7']
# ユニークな値の数: 268004

# %% [markdown]
# # データの正規化

# %%
# !pip install kanjize

# %% [markdown]
# # 市区町村名リストのダウンロード
# trainデータセットの文字列を正規化するために市区町村名のデータセットを使用する

# %%
import pandas as pd
import re
import kanjize

city_path = '/content/drive/My Drive/signate/市区町村名.csv'
# CSVデータをDaskで読み込む
city_data = pd.read_csv(city_path, low_memory=False)

def normalize_address(row):
    city_name = row['市区町村名']
    address = row['大字・丁目名']

    # 大字・丁目名の漢数字をアラビア数字に変換
    kanji_pattern = re.compile(r'[一二三四五六七八九十百千]+')

    def kanji_to_number(match):
        try:
            return str(kanjize.kanji2number(match.group()))
        except ValueError:
            return match.group()

    normalized_address = kanji_pattern.sub(kanji_to_number, address)
    return city_name + " " + normalized_address

# 正規化処理の適用
city_data['正規化住所'] = city_data.apply(normalize_address, axis=1)
print(city_data[['市区町村名', '大字・丁目名', '正規化住所']].head())


# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/city_name_files/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "city_name.csv")

# データをCSVとして保存
city_data.to_csv(output_file_path, index=False)

print(f"データが保存されました: {output_file_path}")
# Out:
#     市区町村名      大字・丁目名             正規化住所
# 0  札幌市中央区       界川一丁目      札幌市中央区 界川1丁目
# 1  札幌市中央区  南十一条西二十二丁目  札幌市中央区 南11条西22丁目
# 2  札幌市中央区  南十一条西二十二丁目  札幌市中央区 南11条西22丁目
# 3  札幌市中央区          盤渓         札幌市中央区 盤渓
# 4  札幌市中央区          盤渓         札幌市中央区 盤渓
# データが保存されました: /content/drive/My Drive/signate/city_name_files/city_name.csv

# %% [markdown]
# # full_addressの正規化

# %%
import pandas as pd
import re
import unicodedata
import kanjize
import os

# 全角・半角の統一
def normalize_text(text):
    if not isinstance(text, str):
        return ''  # テキストが文字列でない場合は空文字を返す
    return unicodedata.normalize('NFKC', text)

# 特殊文字や不要なスペースを削除する関数
def clean_text(text):
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)  # 複数スペースを1つに統一
    text = re.sub(r'[^\w\s]', '', text)  # 特殊文字を削除
    return text

# 漢数字をアラビア数字に変換する関数
def kanji_to_number(match):
    kanji = match.group()
    try:
        return str(kanjize.kanji2number(kanji))
    except ValueError:
        return kanji

# full_address の正規化関数（高速化版）
def normalize_full_address_optimized(full_address, city_mapping):
    """
    full_address: 住所全体（例: 東京都千代田区一番町二丁目）
    city_mapping: 市区町村名をキー、正規化住所を値とする辞書
    """
    if not isinstance(full_address, str):
        return full_address  # 入力が文字列でない場合はそのまま返す

    # 市区町村名を辞書で検索
    for city, normalized_address in city_mapping.items():
        if full_address.startswith(city):
            rest_of_address = full_address[len(city):]
            kanji_pattern = re.compile(r'[一二三四五六七八九十百千]+')
            normalized_rest = kanji_pattern.sub(kanji_to_number, rest_of_address)
            return f"{normalized_address}{normalized_rest}"

    # 市区町村名が一致しない場合はそのまま返す
    return full_address

# データの読み込み
test_path = '/content/drive/My Drive/signate/test/test_selected.csv'
test_data = pd.read_csv(test_path, low_memory=False)

city_path = '/content/drive/My Drive/signate/city_name_files/city_name.csv'
city_data = pd.read_csv(city_path, low_memory=False)

# 市区町村名をキー、正規化住所を値とする辞書を作成
city_mapping = city_data.set_index("市区町村名")["正規化住所"].to_dict()

# full_address の正規化を適用（辞書を使用）
test_data["normalized_full_address"] = test_data["full_address"].apply(
    lambda x: normalize_full_address_optimized(x, city_mapping)
)

# 正規化後のユニークな値の数を確認
print("正規化後のユニークな値数:", test_data['normalized_full_address'].nunique())

# 正規化前と正規化後のデータの一部を表示
print("正規化前後の比較:")
print(test_data[['full_address', 'normalized_full_address']].head())

# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/test/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "test_full_address.csv")

# データをCSVとして保存
test_data.to_csv(output_file_path, index=False)

print(f"正規化後のデータが保存されました: {output_file_path}")
# Out:
# 正規化後のユニークな値数: 268004
# 正規化前後の比較:
#            full_address normalized_full_address
# 0  山口県山陽小野田市大字西高泊618-12    山口県山陽小野田市大字西高泊618-12
# 1       東京都調布市菊野台3丁目3-3         東京都調布市菊野台3丁目3-3
# 2     大阪府泉佐野市下瓦屋1丁目2-48       大阪府泉佐野市下瓦屋1丁目2-48
# 3       愛媛県松山市吉藤5丁目4-23         愛媛県松山市吉藤5丁目4-23
# 4   東京都中央区日本橋蛎殻町1丁目37-9     東京都中央区日本橋蛎殻町1丁目37-9
# 正規化後のデータが保存されました: /content/drive/My Drive/signate/test/test_full_address.csv

# %% [markdown]
# # addr2_nameとekiの正規化処理

# %%
import pandas as pd
import re
import unicodedata
import kanjize

# ファイルを読み込む
test_path = '/content/drive/My Drive/signate/test/test_full_address.csv'
test_data = pd.read_csv(test_path, low_memory=False)

# 全角・半角の統一
def normalize_text(text):
    if not isinstance(text, str):
        return ''  # テキストが文字列でない場合は空文字を返す
    return unicodedata.normalize('NFKC', text)

# 特殊文字や不要なスペースを削除する関数
def clean_text(text):
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)  # 複数スペースを1つに統一
    text = re.sub(r'[\-\(\)\[\]\"\']', '', text)  # 特殊文字を削除
    return text

# 漢数字をアラビア数字に変換する関数
def kanji_to_number(match):
    kanji = match.group()
    try:
        return str(kanjize.kanji2number(kanji))
    except ValueError:
        return kanji

# addr2_name の正規化関数
def normalize_addr2_name(addr2_name):
    # 全角・半角の統一
    addr2_name = normalize_text(addr2_name)

    # 特殊文字や不要なスペースの削除
    addr2_name = clean_text(addr2_name)

    # 漢数字をアラビア数字に変換
    kanji_pattern = re.compile(r'[一二三四五六七八九十百千]+')
    addr2_name = kanji_pattern.sub(kanji_to_number, addr2_name)

    return addr2_name

# eki_name1 の正規化関数
def normalize_eki_name1(eki_name1):
    # 全角・半角の統一
    eki_name1 = normalize_text(eki_name1)

    # 特殊文字や不要なスペースの削除
    eki_name1 = clean_text(eki_name1)

    # 漢数字をアラビア数字に変換
    kanji_pattern = re.compile(r'[一二三四五六七八九十百千]+')
    eki_name1 = kanji_pattern.sub(kanji_to_number, eki_name1)

    return eki_name1


# addr2_name の正規化
test_data["normalized_addr2_name"] = test_data["addr2_name"].apply(normalize_addr2_name)

# eki_name1 の正規化
test_data["normalized_eki_name1"] = test_data["eki_name1"].apply(normalize_eki_name1)

# 正規化後のユニークな値の数を確認
print("addr2_name 正規化後のユニークな値数:", test_data['normalized_addr2_name'].nunique())
print("eki_name1 正規化後のユニークな値数:", test_data['normalized_eki_name1'].nunique())

# 正規化前と正規化後のデータの一部を表示
print("正規化前後の比較:")
print(test_data[['full_address', 'normalized_full_address', 'addr2_name', 'normalized_addr2_name', 'eki_name1', 'normalized_eki_name1']].head())

# 正規化後のデータを保存
output_path = '/content/drive/My Drive/signate/test/normalized_test_addr2_eki.csv'
test_data.to_csv(output_path, index=False)
# Out:
# addr2_name 正規化後のユニークな値数: 61076
# eki_name1 正規化後のユニークな値数: 5987
# 正規化前後の比較:
#            full_address normalized_full_address addr2_name  \
# 0  山口県山陽小野田市大字西高泊618-12    山口県山陽小野田市大字西高泊618-12      大字西高泊
# 1       東京都調布市菊野台3丁目3-3         東京都調布市菊野台3丁目3-3     菊野台３丁目
# 2     大阪府泉佐野市下瓦屋1丁目2-48       大阪府泉佐野市下瓦屋1丁目2-48     下瓦屋１丁目
# 3       愛媛県松山市吉藤5丁目4-23         愛媛県松山市吉藤5丁目4-23      吉藤5丁目
# 4   東京都中央区日本橋蛎殻町1丁目37-9     東京都中央区日本橋蛎殻町1丁目37-9  日本橋蛎殻町１丁目
#
#   normalized_addr2_name eki_name1 normalized_eki_name1
# 0                 大字西高泊       小野田                  小野田
# 1                菊野台3丁目        柴崎                   柴崎
# 2                下瓦屋1丁目       井原里                  井原里
# 3                 吉藤5丁目     本町六丁目                本町6丁目
# 4             日本橋蛎殻町1丁目      水天宮前                 水天宮前

# %% [markdown]
# # JISコードの前処理

# %%
import os
import pandas as pd

test_path = '/content/drive/My Drive/signate/test/normalized_test_addr2_eki.csv'

# CSVデータを読み込む
test_data = pd.read_csv(test_path, low_memory=False)

test_data['addr1_1'] = test_data['addr1_1'].astype(int).apply(lambda x: f"{x:02}")

test_data['addr1_2'] = test_data['addr1_2'].astype(int).apply(lambda x: f"{x:03}")
test_data['area_JIS_code'] = test_data['addr1_1'] + test_data['addr1_2']
print(test_data[['addr1_1', 'addr1_2', 'area_JIS_code']].head(10))  # 結果確認

# area_JIS_codeをカテゴリ型に変換
test_data['area_JIS_code'] = test_data['area_JIS_code'].astype('category')

# addr1_1とaddr1_2列を削除
test_data = test_data.drop(columns=['addr1_1', 'addr1_2'])

# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/test/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "test_jis.csv")

# データをCSVとして保存
test_data.to_csv(output_file_path, index=False)

print(f"データが保存されました: {output_file_path}")
# Out:
#   addr1_1 addr1_2 area_JIS_code
# 0      35     216         35216
# 1      13     208         13208
# 2      27     213         27213
# 3      38     201         38201
# 4      13     102         13102
# 5      29     204         29204
# 6      04     101         04101
# 7      01     106         01106
# 8      27     115         27115
# 9      13     119         13119
# データが保存されました: /content/drive/My Drive/signate/test/test_jis.csv

# %% [markdown]
# # post1の前処理

# %%
import pandas as pd

test_path = '/content/drive/My Drive/signate/test/test_jis.csv'

# CSVデータを文字列型で読み込む
test_data = pd.read_csv(test_path, low_memory=False, dtype={'area_JIS_code': str})

# 'post1' 列を整数型に変換（小数点以下を削除）
test_data['post1'] = test_data['post1'].fillna(0).astype(int)

# post1 を条件に基づきゼロ埋めする関数を定義
def pad_post1(value):
    value = int(value)  # 数値として処理
    if len(str(value)) == 1:  # 1桁の場合
        return f"00{value}"
    elif len(str(value)) == 2:  # 2桁の場合
        return f"0{value}"
    else:  # すでに3桁の場合
        return str(value)

# post1 列を変換
test_data['post1'] = test_data['post1'].apply(pad_post1)

# ユニークな値を取得
unique = test_data['post1'].unique()

# 3桁ではないユニークな値をフィルタリング
not_three_digits = [val for val in unique if len(str(val)) != 3]

# 結果を表示
print("3桁ではないユニークな値:")
print(not_three_digits)

# 3桁ではないユニークな値の数を確認
num_not_three_digits = len(not_three_digits)
print(f"3桁ではないユニークな値の数: {num_not_three_digits}")
# Out:
# 3桁ではないユニークな値:
# []
# 3桁ではないユニークな値の数: 0

# %% [markdown]
# # post2の前処理

# %%
import os

# 'post2' 列を整数型に変換（小数点以下を削除）
test_data['post2'] = test_data['post2'].fillna(0).astype(int)

# post2 を条件に基づきゼロ埋めする関数を定義
def pad_post2(value):
    value = int(value)  # 数値として処理
    if len(str(value)) == 1:  # 1桁の場合
        return f"000{value}"
    elif len(str(value)) == 2:  # 2桁の場合
        return f"00{value}"
    elif len(str(value)) == 3:  # 3桁の場合
        return f"0{value}"
    else:  # すでに4桁の場合
        return str(value)

# post2 列を変換
test_data['post2'] = test_data['post2'].apply(pad_post2)

# zip_code 列を作成（post1 と post2 を結合）
test_data['zip_code'] = test_data['post1'].astype(str) + test_data['post2'].astype(str)

# 結果を確認
print(test_data[['full_address', 'post1', 'post2', 'zip_code']])


# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/test/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "test_post.csv")

# データをCSVとして保存
test_data.to_csv(output_file_path, index=False)

print(f"データが保存されました: {output_file_path}")

# 結果を表示
test_data.head()
# Out:
#                 full_address post1 post2 zip_code
# 0       山口県山陽小野田市大字西高泊618-12   756  0057  7560057
# 1            東京都調布市菊野台3丁目3-3   182  0007  1820007
# 2          大阪府泉佐野市下瓦屋1丁目2-48   598  0062  5980062
# 3            愛媛県松山市吉藤5丁目4-23   791  8011  7918011
# 4        東京都中央区日本橋蛎殻町1丁目37-9   103  0014  1030014
# ...                      ...   ...   ...      ...
# 384535        新潟県見附市上新田町2-11   954  0112  9540112
# 384536      広島県広島市中区上幟町11-15   730  0014  7300014
# 384537          東京都国立市中3丁目10   186  0004  1860004
# 384538      広島県広島市中区八丁堀12-10   730  0013  7300013
# 384539       東京都墨田区向島3丁目39-7   131  0033  1310033
#
# [384540 rows x 4 columns]
# データが保存されました: /content/drive/My Drive/signate/test/test_post.csv
#    index  target_ym          full_address         lon        lat  \
# 0      0     202207  山口県山陽小野田市大字西高泊618-12  131.175432  34.007274
# 1      1     202301       東京都調布市菊野台3丁目3-3  139.569165  35.653207
# 2      2     202307     大阪府泉佐野市下瓦屋1丁目2-48  135.328353  34.418698
# ...

# %% [markdown]
# # 用途地域、都市計画、建蔽率、容積率の前処理

# %%
# ユニークな値を取得
unique = test_data['land_youseki'].unique()

# ユニークな値を確認
print("ユニークな値:")
print(unique)

print(f"ユニークな値の数: {num_unique}")
# Out:
# ユニークな値:
# [      nan 0.000e+00 2.000e+02 5.000e+02 4.000e+02 1.000e+02 3.000e+02
#  8.000e+01 1.500e+02 6.000e+02 7.000e+02 6.000e+01 8.000e+02 1.600e+02
#  3.990e+02 1.840e+02 2.970e+02 5.500e+02 5.000e+01 3.070e+02 4.940e+02
#  2.400e+02 1.990e+02 4.980e+02 1.800e+02 9.999e+03 2.240e+02 1.080e+02
#  3.600e+02 3.700e+02 4.800e+02 1.070e+03 1.640e+02 3.970e+02 2.990e+02
#  3.250e+02 2.910e+02 6.540e+02 3.770e+02 1.630e+02 4.000e+01 3.270e+02
#  2.160e+02 5.610e+02 1.880e+02 3.660e+02 6.990e+02 3.240e+02 3.780e+02
#  3.750e+02 6.250e+02 2.520e+02 5.320e+02 2.000e+01 1.000e+03 5.990e+02
#  6.000e+00 2.700e+02 3.160e+02 3.890e+02 2.500e+02 4.200e+02 2.800e+02
#  3.980e+02 6.960e+02 7.000e+01 5.970e+02 2.640e+02 9.040e+02 1.440e+02
#  3.590e+02 1.680e+02 1.910e+02 3.850e+02 3.880e+02 1.720e+02 2.390e+02
#  2.950e+02 3.350e+02 5.310e+02 9.000e+01 1.760e+02]
# ユニークな値の数: 268004

# %%
print("Test data type:", test_data['land_youseki'].dtype)
# Out:
# Test data type: float64

# %%
import pandas as pd
import numpy as np
import os

test_path = '/content/drive/My Drive/signate/test/test_post.csv'
# CSVデータを読み込む
test_data = pd.read_csv(test_path, low_memory=False, dtype={'area_JIS_code': str, 'zip_code': str})

# 列名を変更する
test_data.rename(columns={'full_address': 'land_address'}, inplace=True)
test_data.rename(columns={'addr2_name': 'sub_address'}, inplace=True)

# 標準的な建蔽率
standard_kenpei = [30, 40, 50, 60, 70, 80]

# 建蔽率の処理関数
def process_kenpei(value):
    if pd.isna(value) or value <= 0 or value > 100:  # 欠損値、0、100超えを処理
        return np.nan
    return min(standard_kenpei, key=lambda x: abs(x - value))  # 最も近い標準値

# 建蔽率の処理
test_data['land_kenpei'] = test_data['land_kenpei'].apply(process_kenpei)

# 標準的な容積率
standard_ratios = [50, 60, 80, 100, 150, 200, 300, 400, 500, 600, 700, 800, 1000]

# 容積率の処理関数
def process_youseki(x):
    if pd.isna(x) or x <= 0:  # 欠損値または0以下を処理
        return 300
    elif x == 9999:  # 異常値
        return 1000
    elif x in standard_ratios:  # 標準値をそのまま
        return x
    elif x > 1000:  # 極端な値を欠損扱い
        return np.nan
    else:  # 非標準値を丸める
        return round(x / 10) * 10

# 容積率の処理
test_data['land_youseki'] = test_data['land_youseki'].apply(process_youseki)

# land_youto と land_toshi の 0 を欠損値に置き換え
test_data['land_youto'] = test_data['land_youto'].replace(0, np.nan)
test_data['land_toshi'] = test_data['land_toshi'].replace(0, np.nan)

# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/test/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "test_kenpei.csv")

# データをCSVとして保存
test_data.to_csv(output_file_path, index=False)

print(f"データが保存されました: {output_file_path}")

# 結果を表示
test_data.head()
# Out:
# データが保存されました: /content/drive/My Drive/signate/test/test_kenpei.csv
#    index  target_ym          land_address         lon        lat  \
# 0      0     202207  山口県山陽小野田市大字西高泊618-12  131.175432  34.007274
# 1      1     202301       東京都調布市菊野台3丁目3-3  139.569165  35.653207
# 2      2     202307     大阪府泉佐野市下瓦屋1丁目2-48  135.328353  34.418698
# 3      3     202207       愛媛県松山市吉藤5丁目4-23  132.758789  33.873232
# 4      4     202201   東京都中央区日本橋蛎殻町1丁目37-9  139.785509  35.682308
#
#    building_structure  year_built  land_youto  land_toshi  land_kenpei  ...  \
# 0                10.0    201101.0         NaN         NaN          NaN  ...
# 1                 4.0    198703.0         NaN         NaN          NaN  ...
# 2                10.0    198904.0         NaN         NaN          NaN  ...
# 3                 1.0    200401.0         1.0         1.0          NaN  ...
# 4                 5.0    198501.0         5.0         1.0          NaN  ...
#
# ...

# %% [markdown]
# # 築年数、year_built_quarterを追加する

# %%
import pandas as pd
import numpy as np
import os

test_path = '/content/drive/My Drive/signate/test/test_kenpei.csv'
# CSVデータを読み込む
test_data = pd.read_csv(test_path, low_memory=False, dtype={'area_JIS_code': str, 'zip_code': str})

# 築年数を計算する関数
def calculate_age(target_ym, year_built):
    """
    target_ym: int (例: 202007)
    year_built: float or int (例: 200210.0)
    築年数を計算して返す
    """
    # 欠損値の場合は NaN を返す
    if pd.isna(target_ym) or pd.isna(year_built):
        return None

    # 年月形式で解釈
    target_year = target_ym // 100
    target_month = target_ym % 100
    built_year = int(year_built // 100)
    built_month = int(year_built % 100)

    # 築年数を計算
    age_years = target_year - built_year
    if target_month < built_month:  # 月が過ぎていない場合
        age_years -= 1

    return max(age_years, 0)  # 築年数が負にならないようにする

# 築年数列を作成
test_data['age_years'] = test_data.apply(lambda row: calculate_age(row['target_ym'], row['year_built']), axis=1)

# 年と月を分解
test_data['year'] = test_data['year_built'] // 100
test_data['month'] = test_data['year_built'] % 100

# 月を小数に変換して加算（12月の場合を考慮）
test_data['year_built_quarter'] = test_data['year'] + (
    (test_data['month'] - 1) / 12
)

# zip_code を文字列型に変換
test_data['zip_code'] = test_data['zip_code'].astype(str)

# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/test/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "test_built_zip.csv")

# データをCSVとして保存
test_data.to_csv(output_file_path, index=False)

print(f"データが保存されました: {output_file_path}")

# 結果の確認
print(test_data[['year_built', 'age_years', 'year_built_quarter', 'zip_code']].head())
# Out:
# データが保存されました: /content/drive/My Drive/signate/test/test_built_zip.csv
#    year_built  age_years  year_built_quarter zip_code
# 0    201101.0       11.0         2011.000000  7560057
# 1    198703.0       35.0         1987.166667  1820007
# 2    198904.0       34.0         1989.250000  5980062
# 3    200401.0       18.0         2004.000000  7918011
# 4    198501.0       37.0         1985.000000  1030014

# %% [markdown]
# # target_ym を四半期形式に変換

# %%
import pandas as pd
import numpy as np
import os

test_path = '/content/drive/My Drive/signate/test/test_built_zip.csv'

# CSVデータを読み込む
test_data = pd.read_csv(test_path, low_memory=False, dtype={'area_JIS_code': str, 'zip_code': str})


# 月ごとの四半期マッピング
quarter_mapping = {
    1: 0.25,  # Q1
    7: 0.75   # Q3
}

# target_ym を四半期形式に変換
def convert_to_quarter(target_ym):
    year = target_ym // 100  # 年部分を抽出
    month = target_ym % 100  # 月部分を抽出
    quarter = quarter_mapping.get(month, 0)  # 四半期にマッピング
    return year + quarter

test_data["target_quarter"] = test_data["target_ym"].apply(convert_to_quarter)

# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/test/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "test_target_quarter.csv")

# データをCSVとして保存
test_data.to_csv(output_file_path, index=False)

print(f"データが保存されました: {output_file_path}")

test_data.head()
# Out:
# データが保存されました: /content/drive/My Drive/signate/test/test_target_quarter.csv
#    index  target_ym          land_address         lon        lat  \
# 0      0     202207  山口県山陽小野田市大字西高泊618-12  131.175432  34.007274
# 1      1     202301       東京都調布市菊野台3丁目3-3  139.569165  35.653207
# 2      2     202307     大阪府泉佐野市下瓦屋1丁目2-48  135.328353  34.418698
# 3      3     202207       愛媛県松山市吉藤5丁目4-23  132.758789  33.873232
# 4      4     202201   東京都中央区日本橋蛎殻町1丁目37-9  139.785509  35.682308
#
#    building_structure  year_built  land_youto  land_toshi  land_kenpei  ...  \
# 0                10.0    201101.0         NaN         NaN          NaN  ...
# 1                 4.0    198703.0         NaN         NaN          NaN  ...
# 2                10.0    198904.0         NaN         NaN          NaN  ...
# 3                 1.0    200401.0         1.0         1.0          NaN  ...
# 4                 5.0    198501.0         5.0         1.0          NaN  ...
#
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384540 entries, 0 to 384539
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   index                    384540 non-null  int64
#  1   target_ym                384540 non-null  int64
#  2   land_address             384540 non-null  object
#  3   lon                      384540 non-null  float64
#  4   lat                      384540 non-null  float64
#  5   building_structure       383548 non-null  float64
#  6   year_built               383619 non-null  float64
#  7   land_youto               91656 non-null   float64
#  8   land_toshi               83677 non-null   float64
#  9   land_kenpei              52927 non-null   float64
#  10  land_youseki             384538 non-null  float64
#  11  post1                    384540 non-null  int64
#  12  post2                    384540 non-null  int64
# ...

# %% [markdown]
# # 不要な列を削除する

# %%
import pandas as pd
import numpy as np
import os

# データを読み込む
test_path = '/content/drive/My Drive/signate/test/test_target_quarter.csv'
test_data = pd.read_csv(test_path, low_memory=False, dtype={'area_JIS_code': str, 'zip_code': str})

# 削除したい列
columns_to_drop = [
    'target_ym',
    'land_address',
    'post1',
    'post2',
    'sub_address',
    'eki_name1',
    'flg_new',
    'year',
    'month'
]

# データから不要な列を削除
test_data = test_data.drop(columns=columns_to_drop, errors='ignore')

# カテゴリ型に変換したい列
columns_to_categorize = [
    'building_structure',
    'land_youto',
    'land_toshi',
    'snapshot_window_angle',
    'madori_kind_all',
    'normalized_full_address',
    'normalized_addr2_name',
    'normalized_eki_name1',
    'area_JIS_code',
    'zip_code'
]

# カテゴリ型に変換
for col in columns_to_categorize:
    if col in test_data.columns:
        test_data[col] = test_data[col].astype('category')

# 処理結果の確認
print(test_data.info())


# 保存先のGoogle Driveフォルダのパス
folder_path = "/content/drive/My Drive/signate/test/"

# フォルダが存在しない場合は作成
os.makedirs(folder_path, exist_ok=True)

# 保存先のファイルパス
output_file_path = os.path.join(folder_path, "test_proceed.csv")

# データをCSVとして保存
test_data.to_csv(output_file_path, index=False)

print(f"データが保存されました: {output_file_path}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384540 entries, 0 to 384539
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   index                    384540 non-null  int64
#  1   lon                      384540 non-null  float64
#  2   lat                      384540 non-null  float64
#  3   building_structure       383548 non-null  category
#  4   year_built               383619 non-null  float64
#  5   land_youto               91656 non-null   category
#  6   land_toshi               83677 non-null   category
#  7   land_kenpei              52927 non-null   float64
#  8   land_youseki             384538 non-null  float64
#  9   walk_distance1           382058 non-null  float64
#  10  house_area               384540 non-null  float64
#  11  snapshot_window_angle    307842 non-null  category
#  12  madori_number_all        384540 non-null  int64
# ...
